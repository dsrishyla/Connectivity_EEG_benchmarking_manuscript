           0.0002059085318908912, 0.0003468126433866407, 0.00033734440701426924, 0.000416613291317048, 
           0.00016384501127594668, 0.0002332679487848627, 0.0002630324067927487, 0.0002811609676769324, 
           0.0004416234488107076, 0.0004665145082780707, 0.0005364765339766343, 0.00034334190476065967, 
           0.0002987447332785194, 0.0003728596501311266, 0.000562963131837228, 0.0008021141740559967, 
           0.0009779153696119448, 0.00026679350866011406, 9.628615280279496e-05, 0.00010284007166156809]}

# %%
gpdc_ec_large = [5.687540748605812e+59]
ddtf_ec_large = [1.3738637875663498e+24]
gpdc_eo_large =[1.2954300820079088e+62, 4.528259656049023e+59, 1.863497758472227e+53,2.4059204053287492e+51]
ddtf_eo_large = [3.4154565181710212e+28,4.567401918241959e+27,2.846691411703304e+27,2.5741619055404873e+26]

# %%
"""extracted_gpdc_ec = [0.03231519225997922, 0.015969234040205303, 0.03949445818970472]
extracted_ddtf_ec = [0.0002056704773496393,0.00024593714411879605, 0.0002072706542516712]"""

# %%
ec_means = {'gpdc':0.0406, 'psgp':0.0012, 'ddtf':0.00034}
eo_means = {'gpdc':0.0383, 'psgp':0.0013, 'ddtf':0.0004}
ec_stds = {'gpdc': 0.016, 'psgp':0.0004, 'ddtf':0.0002}
eo_stds = {'gpdc':0.0134, 'psgp':0.0005, 'ddtf':0.0002}

# %%
p_vals = {}
d_vals = {}
methods = ['psgp','gpdc','ddtf']
for method in methods:

    wilcox, p = stats.ttest_ind(mean_lists_ec[method], mean_lists_eo[method])
    p_vals[method] = p
    
    pooled_sd = np.sqrt((((len(mean_lists_ec[method])-1)*(ec_stds[method]**2) + (len(mean_lists_eo[method])-1)*(eo_stds[method])**2))/(len(mean_lists_ec[method]) + len(mean_lists_eo[method]) - 2))
    cohens_d = (ec_means[method]- eo_means[method])/pooled_sd
    d_vals[method] = cohens_d

# %%
p_vals
# Out:
# {'psgp': 0.5603894310187804,
#  'gpdc': 0.24653206315676326,
#  'ddtf': 0.028821995635729847}

# %%
d_vals
# Out:
# {'psgp': -0.22086305214969318,
#  'gpdc': 0.15566205363419527,
#  'ddtf': -0.29999999999999993}

# %%
#LOWER HALF OF MATRIX

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))

ind = np.arange(len(ec_means))  # the x locations for the groups
width = 0.35  # the width of the bars

rects1 = ax.bar(ind - width/2, [ec_means['gpdc'], ec_means['ddtf'], ec_means['psgp']], width, yerr=[ec_stds['gpdc'],ec_stds['ddtf'],ec_stds['psgp']],
                label='EC')
rects2 = ax.bar(ind + width/2, [eo_means['gpdc'], eo_means['ddtf'], eo_means['psgp']], width, yerr=[eo_stds['gpdc'],eo_stds['ddtf'],eo_stds['psgp']],
                label='EO')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mean connectivity',fontsize=14,fontweight='bold')
ax.set_xlabel('Methods',fontsize=14,fontweight='bold')
ax.set_xticks(ind)
ax.set_xticklabels(('gPDC', 'dDTF', 'pSGP'),fontsize=14)
ax.text(-0.1, .055, f"D={d_vals['gpdc']:.3f}",fontsize=14)
ax.text(0.8, .03, f"D={d_vals['ddtf']:.3f}",fontsize=14)
ax.text(1.8, 0.01, f"D={d_vals['psgp']:.3f}",fontsize=14)
ax.legend()
ax.set_title('Direction 1',fontsize=16, fontweight='bold')
fig.tight_layout()
plt.savefig('figs/real_means_eff_1.png',dpi=300)

# %% [markdown]
# #### UPPER HALF OF MATRIX

# %%
ec_means_upper = {'psgp': 0.0012751134174966074, 'gpdc': 0.03985322482873172, 'ddtf': 0.0003451454833682503}
eo_means_upper = {'psgp': 0.0012716678296438185, 'gpdc': 0.03764776740154189, 'ddtf': 0.0004177768221431659}
ec_stds_upper = {'psgp': 0.0004889197618606711, 'gpdc': 0.015415631319562136, 'ddtf': 0.00020699642349428457}
eo_stds_upper = {'psgp': 0.0004324547152859414, 'gpdc': 0.013607626171232033, 'ddtf': 0.00022673277215509748}
p_vals_upper = {'psgp': 0.9556987698832013, 'gpdc': 0.2655822867794028, 'ddtf': 0.014455619623668854}
d_vals_upper = {'psgp': 0.007465229104489623, 'gpdc': 0.15155463200493965, 'ddtf': -0.3347796438371131}

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))

ind = np.arange(len(ec_means))  # the x locations for the groups
width = 0.35  # the width of the bars

rects1 = ax.bar(ind - width/2, [ec_means_upper['gpdc'], ec_means_upper['ddtf'], ec_means_upper['psgp']], width, yerr=[ec_stds_upper['gpdc'],ec_stds_upper['ddtf'],ec_stds_upper['psgp']],
                label='EC')
rects2 = ax.bar(ind + width/2, [eo_means_upper['gpdc'], eo_means_upper['ddtf'], eo_means_upper['psgp']], width, yerr=[eo_stds_upper['gpdc'],eo_stds_upper['ddtf'],eo_stds_upper['psgp']],
                label='EO')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mean connectivity',fontsize=14,fontweight='bold')
ax.set_xlabel('Methods',fontsize=14,fontweight='bold')
ax.set_xticks(ind)
ax.set_xticklabels(('gPDC', 'dDTF', 'pSGP'),fontsize=14)
ax.text(-0.1, .055, f"D={d_vals_upper['gpdc']:.3f}",fontsize=14)
ax.text(0.8, .03, f"D={d_vals_upper['ddtf']:.3f}",fontsize=14)
ax.text(1.8, 0.01, f"D={d_vals_upper['psgp']:.3f}",fontsize=14)
ax.legend()
ax.set_title('Direction 2',fontsize=16, fontweight='bold')
fig.tight_layout()
plt.savefig('figs/real_means_eff_2.png',dpi=300)

# %%
figures = ['figs/real_means_eff_1.png','figs/real_means_eff_2.png']
margin = 300
fig, axes = plt.subplots(2, 1, figsize=(18,6))
for figure, ax in zip(figures, axes.ravel()):
    img = mpimg.imread(f"{figure}")
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    ax.set(frame_on=False)
    
    ax.imshow(img)        
    #ax.set_aspect()    
plt.subplots_adjust(wspace=0, hspace=0)
#fig.tight_layout(rect=[-0.01, -0.02, 1.02, 1.02], w_pad=0.0, h_pad=0.0)
fig.tight_layout()
fig.savefig("figs/real_means_eff.png", bbox_inches='tight',dpi=300)
