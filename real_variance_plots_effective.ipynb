                              4.95646167154929, 4.531105124443778, 5.752395816472318, 3.6906025742989335, 4.046748042391878, 
                              4.289474499606485, 4.8811759692678685, 4.625944069462377, 4.399290960803661]}

# %%
#EXAMINING DISTRIBUTIONS TO UNDERSTAND SIGNIFICANCE

# %%
#4-panel figure to show inter vs intra differences for each method
fig, axes = plt.subplots(1,3,figsize=(8,4))
for method, ax in list(zip(methods,axes.ravel())):
    sns.histplot(inter_variance_dict[method], ax=ax, color='darkslategray',label="between-subject")
    sns.histplot(intra_variance_dict[method], ax=ax, color='lightgray', label="within-subject")
    ax.set_ylabel("")

axes[0].set_title('gPDC')
axes[1].set_title('pSGP')
axes[2].set_title('dDTF')

fig.supxlabel('Coefficient of variance (CV)')
fig.supylabel('Counts of observations')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, fontsize=9, bbox_to_anchor=(1,0.125))
fig.tight_layout()

fig.savefig('inter_intra_plots_effective.png', dpi=300)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
fig, axes = plt.subplots(1,1)

sns.histplot(inter_variance_dict['gPDC'], color='darkslategray',label = 'gPDC')
axes.set_ylabel("")
sns.histplot(inter_variance_dict['dDTF'], color='lightgray', label = 'dDTF')
axes.set_ylabel("")
sns.histplot(inter_variance_dict['pSGP'], color = "lightgray", label='pSGP')
axes.set_ylabel("")

fig.supxlabel('Coefficient of variance (CV)')
fig.supylabel('Counts of observations')

fig.legend(bbox_to_anchor=(0.98,0.98))

fig.tight_layout()

fig.savefig('inter_variance_plots_effective.png', dpi=300)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, axes = plt.subplots(1,1)

sns.histplot(intra_variance_dict['gPDC'], color='darkslategray',label = 'gPDC')
axes.set_ylabel("")
sns.histplot(intra_variance_dict['dDTF'], color='lightgray', label = 'dDTF')
axes.set_ylabel("")
sns.histplot(intra_variance_dict['pSGP'], color = "lightgray", edgecolor='gray',label='pSGP')
axes.set_ylabel("")

fig.supxlabel('Coefficient of variance (CV)')
fig.supylabel('Counts of observations')

fig.legend(bbox_to_anchor=(0.98,0.98))

fig.tight_layout()

fig.savefig('intra_variance_plots_effective.png', dpi=300)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#significance test redo

# %%
#Functions

def outlier_indices(data):
    q1 = np.percentile(data, 25, method='midpoint')
    q3 = np.percentile(data, 75, method='midpoint')
    iqr = q3 - q1
    upper = q3 + 1.5 * iqr
    lower = q1 - 1.5 * iqr
    upper_outliers = np.where(data >= upper)[0]
    lower_outliers = np.where(data <= lower)[0]
    outlier_index_list = list(upper_outliers) + list(lower_outliers)
    
    return outlier_index_list

def remove_outliers(data):
    outliers_removed = []
    
    for i in range(0,len(data)):
        if i not in outlier_indices(data):
            outliers_removed.append(data[i])
            
    return outliers_removed

def bootstrap_t(group1, group2):
    p_val_dict = {}
    
    #calculate original t statistic
    mean1 = np.mean(group1)
    mean2 = np.mean(group2)
    
    sd1 = np.std(group1)
    sd2 = np.std(group2)
    
    #calculate length of inter
    n1 = len(group1)
    
    #calculate length of intra
    n2 = len(group2)
    
    #calculate total n
    total_n = n1 + n2
        
    pooled_sd = np.sqrt(((n1-1)*(sd1**2) + (n2-1)*(sd2**2))/(n1 + n2 - 2))
    
    t_orig = (mean1 - mean2)/(pooled_sd * np.sqrt((1/n1) + (1/n2)))
    
    #create pooled sample
    pooled_sample = group1 + group2
    
    ####################################################
    #sample from pooled 1000 times
    bootstrap_sample1 = []
    bootstrap_sample2 = []
    
    for i in range(1000):
        sample1 = []
        sample2 = []
        index1 = np.random.choice(range(0,total_n),n1,replace=False)
        index2 = np.random.choice(range(0,total_n),n2,replace=False)
        sample1 = np.array(pooled_sample)[index1]
        sample2 = np.array(pooled_sample)[index2]
        bootstrap_sample1.append(sample1)
        bootstrap_sample2.append(sample2)
        
    #calculate the t-statistic in each
    bootstrap_t_stats = []
    for i in range(1000):
        mean1 = np.mean(bootstrap_sample1[i])
        mean2 = np.mean(bootstrap_sample2[i])
        
        sd1 = np.std(bootstrap_sample1[i])
        sd2 = np.std(bootstrap_sample2[i])
        
        n1 = len(bootstrap_sample1[i])
        n2 = len(bootstrap_sample2[i])
        
        pooled_sd = np.sqrt(((n1-1)*(sd1**2) + (n2-1)*(sd2**2))/(n1 + n2 - 2))
        
        t = (mean1 - mean2)/(pooled_sd * np.sqrt((1/n1) + (1/n2)))
    
        bootstrap_t_stats.append(t)
    
    count = 0
    for t in bootstrap_t_stats:
        if t > t_orig:
            count += 1

    p_val = count/1000
    p_val_corr = p_val * 3

    return p_val_corr

# %%
p_val_dict = {}
for method in methods:
    p_val_dict[method] = bootstrap_t(inter_variance_dict[method],intra_variance_dict[method])

# %%
print('Inter vs Intra comparisons:',p_val_dict)
# Out:
# Inter vs Intra comparisons: {'gPDC': 0.0, 'pSGP': 0.62, 'dDTF': 2.212}

# %%
comparison_pairs = [('gPDC','pSGP'),('gPDC','dDTF'),('pSGP','dDTF')]

# %%
inter_p_val_dict = {}

for pair in comparison_pairs:
    method1 = pair[0]
    method2 = pair[1]

    inter_p_val_dict[pair] = bootstrap_t(inter_variance_dict[method1], inter_variance_dict[method2])

intra_p_val_dict = {}

for pair in comparison_pairs:
    method1 = pair[0]
    method2 = pair[1]

    intra_p_val_dict[pair] = bootstrap_t(intra_variance_dict[method1], intra_variance_dict[method2])

# %%
print('Inter-variance comparison across measures',inter_p_val_dict)
# Out:
# Inter-variance comparison across measures {('gPDC', 'pSGP'): 0.0, ('gPDC', 'dDTF'): 3.0, ('pSGP', 'dDTF'): 3.0}

# %%
print('Intra-variance comparison across measures',intra_p_val_dict)
# Out:
# Intra-variance comparison across measures {('gPDC', 'pSGP'): 0.0, ('gPDC', 'dDTF'): 3.0, ('pSGP', 'dDTF'): 3.0}

# %%
#TROUBLESHOOT T

# %%
#calculate original t statistic
group1 = inter_variance_dict['gPDC']
group2 = inter_variance_dict['dDTF']

mean1 = np.mean(group1)
mean2 = np.mean(group2)

sd1 = np.std(group1)
sd2 = np.std(group2)

#calculate length of inter
n1 = len(group1)

#calculate length of intra
n2 = len(group2)

#calculate total n
total_n = n1 + n2
    
pooled_sd = np.sqrt(((n1-1)*(sd1**2) + (n2-1)*(sd2**2))/(n1 + n2 - 2))

t_orig = (mean1 - mean2)/(pooled_sd * np.sqrt((1/n1) + (1/n2)))

# %%
t_orig
# Out:
# 59.408512793647105

# %%
#create pooled sample
pooled_sample = group1 + group2

####################################################
#sample from pooled 1000 times
bootstrap_sample1 = []
bootstrap_sample2 = []

for i in range(1000):
    sample1 = []
    sample2 = []
    index1 = np.random.choice(range(0,total_n),n1,replace=False)
    index2 = np.random.choice(range(0,total_n),n2,replace=False)
    sample1 = np.array(pooled_sample)[index1]
    sample2 = np.array(pooled_sample)[index2]
    bootstrap_sample1.append(sample1)
    bootstrap_sample2.append(sample2)

# %%
total_n
# Out:
# 216

# %% [markdown]
# #
